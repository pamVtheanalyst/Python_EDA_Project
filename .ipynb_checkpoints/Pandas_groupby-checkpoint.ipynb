# %% [markdown]
# ## Group By

# %%
import pandas as pd

# %%
df = pd.read_csv("visitors_per_shop.csv")

df
# Out:
#          day   shop  visitors  units_sold weather
# 0   1/1/2023  shop1        32           6    Rain
# 1   1/2/2023  shop1        36           7   Sunny
# 2   1/3/2023  shop1        28          12    Snow
# 3   1/4/2023  shop1        33           7   Sunny
# 4   1/1/2023  shop2        90           5   Sunny
# 5   1/2/2023  shop2        85          12  Cloudy
# 6   1/3/2023  shop2        87          15  Cloudy
# 7   1/4/2023  shop2        92           5    Rain
# 8   1/1/2023  shop3        45          20   Sunny
# 9   1/2/2023  shop3        50          13  Cloudy
# 10  1/3/2023  shop3        54           8  Cloudy
# 11  1/4/2023  shop3        42          10  Cloudy

# %%
g = df.groupby('shop')

g

# %%
for shop, data in g:
    print("shop:", shop)
    print('\n')
    print("data:", data)
# Out:
# shop: shop1
#
#
# data:         day   shop  visitors  units_sold weather
# 0  1/1/2023  shop1        32           6    Rain
# 1  1/2/2023  shop1        36           7   Sunny
# 2  1/3/2023  shop1        28          12    Snow
# 3  1/4/2023  shop1        33           7   Sunny
# shop: shop2
#
#
# data:         day   shop  visitors  units_sold weather
# 4  1/1/2023  shop2        90           5   Sunny
# 5  1/2/2023  shop2        85          12  Cloudy
# 6  1/3/2023  shop2        87          15  Cloudy
# 7  1/4/2023  shop2        92           5    Rain
# shop: shop3
#
#
# data:          day   shop  visitors  units_sold weather
# 8   1/1/2023  shop3        45          20   Sunny
# 9   1/2/2023  shop3        50          13  Cloudy
# 10  1/3/2023  shop3        54           8  Cloudy
# 11  1/4/2023  shop3        42          10  Cloudy

# %%
g.get_group("shop1")
# Out:
#         day   shop  visitors  units_sold weather
# 0  1/1/2023  shop1        32           6    Rain
# 1  1/2/2023  shop1        36           7   Sunny
# 2  1/3/2023  shop1        28          12    Snow
# 3  1/4/2023  shop1        33           7   Sunny

# %%
g.max()
# Out:
#             day  visitors  units_sold weather
# shop
# shop1  1/4/2023        36          12   Sunny
# shop2  1/4/2023        92          15   Sunny
# shop3  1/4/2023        54          20   Sunny

# %%
g.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# ...

# %%
g.min()
# Out:
#             day  visitors  units_sold weather
# shop
# shop1  1/1/2023        28           6    Rain
# shop2  1/1/2023        85           5  Cloudy
# shop3  1/1/2023        42           8  Cloudy

# %%
g.describe()
# Out:
#       visitors                                                  units_sold  \
#          count   mean       std   min    25%   50%    75%   max      count
# shop
# shop1      4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0        4.0
# shop2      4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0        4.0
# shop3      4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0        4.0
#
#
#         mean       std  min   25%   50%    75%   max
# shop
# shop1   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# shop2   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# shop3  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
g.size()

# %%
g.count()

# %%
g.plot()
